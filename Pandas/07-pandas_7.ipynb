# %%
# importamos todas las librerías que necesitamos

import pandas as pd
pd.options.display.max_columns = None
import re
import regex as re
import numpy as np
import datetime

# %% [markdown]
# ### Pair Programming Pandas VII
#
# En el ejercicio de ayer estuvimos viendo el groupby y pudimos observar que los datos estaban un poco sucios... 😭. En los ejercicios de hoy pondremos en práctica los apply, y nos crearemos algunas funciones que nos van a permitir limpiar un poco los datos, para que podamos extraer conclusiones de una forma más sencilla.

# %%
df = pd.read_csv("05-attacks_union.csv", index_col = 0)
df.head(5)
# Out:
#   case_number    year        type    country             area  \
# 0  2018.06.25  2018.0     Boating        USA       California
# 1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing             male   M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos    M  NaN
#
#             time          species  \
# 0          18h00      White shark
# 1  14h00  -15h00              NaN
# 2          07h45              NaN
# ...

# %% [markdown]
# ### 1. Cread una columna nueva y una función que nos dé el mes en el que ocurrió el ataque.
#
# Tened en cuenta que no todas las filas tienen la misma estructura
# y que puede que no haya la información de mes. En ese caso devolved un nulo (NaN).
# 💡 Pista 💡Podéis usar regex.

# %%
date_unique = df["date"].unique()
date_unique
# Out:
# array(['25-Jun-2018', '18-Jun-2018', '09-Jun-2018', ..., 'Mar-1803',
#        'Reported Apr-13-1802', 'Reported 18-Dec-1801'], dtype=object)

# %%
df_reported = {col: col.replace("Reported ", "") for col in df}
df_reported.head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_14699/294869738.py in <module>
#       1 df_reported = {col: col.replace("Reported ", "") for col in df}
# ----> 2 df_reported.head(5)
#
# AttributeError: 'dict' object has no attribute 'head'

# %%
def fecha(x):
    return re.findall(r"[A-Z]*[a-z]{2}")[0]

# %%
fecha(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_14699/2073958385.py in <module>
# ----> 1 fecha(df)
#
# /tmp/ipykernel_14699/2615740696.py in fecha(x)
#       1 def fecha(x):
# ----> 2     return re.findall(r"[A-Z]*[a-z]{2}")[0]
#
# TypeError: findall() missing 1 required positional argument: 'string'

# %%
df["Mes"] = df["date"].apply(fecha)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_14699/2484595769.py in <module>
# ----> 1 df["Mes"] = df["date"].apply(fecha)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1103
#    1104         # self.f is Callable
# -> 1105         return self.apply_standard()
#    1106
#    1107     def agg(self):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#    1154             else:
#    1155                 values = obj.astype(object)._values
# -> 1156                 mapped = lib.map_infer(
# ...

# %% [markdown]
# ### 2. Vamos con la columna fatal_(y/n).
# Lo primero que tenéis que hacer es evaluar los valores únicos que hay. Esperaríamos tener solo dos valores: y y n, pero tristemente no será así 😭. Cread una columna nueva y una función que devuelva únicamente y o n y que devuelva un nulo (NaN) si no se encuentra el valor.

# %%
df["fatal_(y/n)"].unique()
# Out:
# array(['N', 'Y', nan, 'M', 'UNKNOWN', '2017', ' N', 'N ', 'y'],
#       dtype=object)

# %%
def yn(x):
    if x == "N":
        return "N"
    elif x == "Y":
        return "Y"
    elif x == " N":
        return "N"
    elif x == "N ":
        return "N"
    elif x == "y":
        return "Y"
    else:
        return np.nan

# %%
df["fatal"] = df["fatal_(y/n)"].apply(yn)
df.head(2)
# Out:
#   case_number    year        type country        area  \
# 0  2018.06.25  2018.0     Boating     USA  California
# 1  2018.06.18  2018.0  Unprovoked     USA     Georgia
#
#                          location  activity             name sex age  \
# 0     Oceanside, San Diego County  Paddling      Julie Wolfe   F  57
# 1  St. Simon Island, Glynn County  Standing  Adyson McNeely    F  11
#
#             time      species  \
# 0          18h00  White shark
# 1  14h00  -15h00          NaN
#
#                                                 href Case Number  Year Type  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN   NaN  NaN
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...         NaN   NaN  NaN
#
#   Country Area Location Activity Name Sex   Age Time Species   \
# 0     NaN  NaN      NaN      NaN  NaN  NaN  NaN  NaN      NaN
# 1     NaN  NaN      NaN      NaN  NaN  NaN  NaN  NaN      NaN
#
# ...

# %%
df["fatal"].unique()
# Out:
# array(['N', 'Y', nan], dtype=object)

# %% [markdown]
# ### 3. Seguid la misma lógica que en el ejercicio anterior pero con la columna sex.
# Pero en este caso vamos a incluir un retito más: En este caso querremos tener dos valores únicos F y M. De nuevo en la columna hay otros carácteres raros como 'M ', 'lli', 'N', '.'. En esos casos, queremos que se reemplacen por M o F de forma aleatoria (tendréis que usar la librería random). En caso de que sea nulo, que la función devuelva nulo (np.nan).

# %%
df["sex"].unique()
# Out:
# array(['F', 'M', nan, 'M ', 'lli', 'N', '.'], dtype=object)

# %%
def reemplazar_mf(x):
    if x == "F":
        return "F"
    elif x == "M":
        return "M"
    else:
        return np.nan

# %%
df["sex_fm"] = df["sex"].apply(reemplazar_mf)
df.head(5)
# Out:
#   case_number    year        type    country             area  \
# 0  2018.06.25  2018.0     Boating        USA       California
# 1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing             male   M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos    M  NaN
#
#             time          species  \
# 0          18h00      White shark
# 1  14h00  -15h00              NaN
# 2          07h45              NaN
# ...

# %%
df["sex_fm"].unique()
# Out:
# array(['F', 'M', nan], dtype=object)

# %% [markdown]
# ### 4. Una vez que hayáis terminado eliminad las columnas originales conservando las nuevas.

# %%
df.drop(["fatal_(y/n)", "sex"], axis = 1, inplace = True)

# %%
df.head(5)
# Out:
#   case_number    year        type    country             area  \
# 0  2018.06.25  2018.0     Boating        USA       California
# 1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    11
# 2                    Habush, Oahu      Surfing      John Denges   48
# 3              Arrawarra Headland      Surfing             male  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos   NaN
#
#             time          species  \
# 0          18h00      White shark
# 1  14h00  -15h00              NaN
# 2          07h45              NaN
# ...

# %% [markdown]
# ### 5. Guardad el dataframe en un csv que usaremos más adelante.

# %%
df.to_csv("07-attack.csv")
